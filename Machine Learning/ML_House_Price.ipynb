# %%
# Loads necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Loads the homes.csv dataset
homes = pd.read_csv('homes.csv')
homes
# Out:
#     ID  Price  Floor  Lot  Bath  Bed  BathBed  Year  Age  AgeSq  Gar  Status
# 0    1  388.0  2.180    4   3.0    4     12.0  1940 -3.0   9.00    0    Sold  \
# 1    2  450.0  2.054    5   3.0    4     12.0  1957 -1.3   1.69    2    Sold
# 2    3  386.0  2.112    5   2.0    4      8.0  1955 -1.5   2.25    2    Sold
# 3    4  350.0  1.442    6   1.0    2      2.0  1956 -1.4   1.96    1  Active
# 4    5  155.5  1.800    1   2.0    4      8.0  1994  2.4   5.76    1    Sold
# ..  ..    ...    ...  ...   ...  ...      ...   ...  ...    ...  ...     ...
# 71  72  249.9  2.081    5   2.1    4      8.4  1970  0.0   0.00    1    Sold
# 72  73  215.0  2.044    1   1.1    4      4.4  1936 -3.4  11.56    0    Sold
# 73  74  435.0  2.253   11   2.0    3      6.0  1979  0.9   0.81    2    Sold
# 74  75  274.9  1.861    4   2.0    4      8.0  1995  2.5   6.25    2  Active
# 75  76  349.5  2.896    4   3.0    5     15.0  1979  0.9   0.81    2  Active
#
#     DAc   School  DEd  DHa  DAd  DCr  DPa
# ...

# %%
# Loads predictor and target variables
X = homes[['Bed','Floor', 'Bath']]
y = homes[['Price']]

# %%
# Splits the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, np.ravel(y),random_state=123)

# %%
# Initializes and trains a multilayer perceptron regressor model on the training and validation sets
# This cell takes a long to run.
mlpReg_train = MLPRegressor(random_state=1, max_iter=500000, hidden_layer_sizes=[3,2]).fit(X_train, np.ravel(y_train))
mlpReg_validation = MLPRegressor(random_state=1, max_iter=500000, hidden_layer_sizes=[1]).fit(X_test, np.ravel(y_test))

# %%
# Predicts the price of a 5 bedroom house with 2,896 sq ft
y_pred = mlpReg_train.predict([[5, 2.896, 4]])
y_pred
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# array([285.60519969])

# %%
# Plots the loss curves for the training and validation sets
f, ax = plt.subplots(1, 1)
sns.lineplot(x=range(len(mlpReg_train.loss_curve_)),y = mlpReg_train.loss_curve_, label='Training')
sns.lineplot(x=range(len(mlpReg_validation.loss_curve_)),y = mlpReg_validation.loss_curve_, label='Validation')
ax.set_xlabel('Epochs', fontsize=14)
ax.set_ylabel('Loss', fontsize=14)
# Out:
# Text(0, 0.5, 'Loss')

# %%
# Obtains the final weights and biases
print("Weights:", mlpReg_train.coefs_)
print("Bias:", mlpReg_train.intercepts_)
# Out:
# Weights: [array([[-2.58432222e-316,  5.85827095e-316,  3.02767034e-317],
#        [-7.03096589e-316, -9.53809638e-317,  7.88985732e-317],
#        [-2.69363394e-316, -7.86376230e-316, -9.13769239e-316]]), array([[ 9.90627568e-316, -5.86646517e-316],
#        [-8.18943566e-316, -4.98018947e-316],
#        [-1.16988302e-315,  1.09729851e-315]]), array([[-9.68608886e-316],
#        [-3.67274197e-316]])]
# Bias: [array([ 0.07763347, -0.16161097,  0.370439  ]), array([-0.78787274, -0.6614265 ]), array([285.60519969])]
